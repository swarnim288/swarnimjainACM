# %% [markdown]
# <a href="https://colab.research.google.com/github/swarnim288/swarnimjainACM/blob/main/swarnimjain.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/smoking_driking_dataset_Ver01.csv')

# %%
df.head(5)
# Out:
#     sex  age  height  weight  waistline  sight_left  sight_right  hear_left  \
# 0  Male   35   170.0    75.0       90.0         1.0          1.0        1.0
# 1  Male   30   180.0    80.0       89.0         0.9          1.2        1.0
# 2  Male   40   165.0    75.0       91.0         1.2          1.5        1.0
# 3  Male   50   175.0    80.0       91.0         1.5          1.2        1.0
# 4  Male   50   165.0    60.0       80.0         1.0          1.2        1.0
#
#    hear_right    SBP  ...  LDL_chole  triglyceride  hemoglobin  urine_protein  \
# 0         1.0  120.0  ...      126.0          92.0        17.1            1.0
# 1         1.0  130.0  ...      148.0         121.0        15.8            1.0
# 2         1.0  120.0  ...       74.0         104.0        15.8            1.0
# 3         1.0  145.0  ...      104.0         106.0        17.6            1.0
# 4         1.0  138.0  ...      117.0         104.0        13.8            1.0
#
# ...

# %%
df.tail(5)
# Out:
#          sex  age  height  weight  waistline  sight_left  sight_right  \
# 210985  Male   35   175.0    55.0       72.5         1.2          1.0
# 210986  Male   35   185.0    90.0       88.0         0.7          0.5
# 210987  Male   35   170.0    70.0       83.0         1.2          1.5
# 210988  Male   45   175.0    60.0       70.0         1.5          1.5
# 210989  Male    5     NaN     NaN        NaN         NaN          NaN
#
#         hear_left  hear_right    SBP  ...  LDL_chole  triglyceride  \
# 210985        1.0         1.0  140.0  ...       93.0          79.0
# 210986        1.0         1.0  124.0  ...       94.0         527.0
# 210987        1.0         1.0  125.0  ...      149.0         155.0
# 210988        1.0         1.0  115.0  ...      117.0          85.0
# 210989        NaN         NaN    NaN  ...        NaN           NaN
#
#         hemoglobin  urine_protein  serum_creatinine  SGOT_AST  SGOT_ALT  \
# ...

# %%
df.dtypes
# Out:
# sex                  object
# age                   int64
# height              float64
# weight              float64
# waistline           float64
# sight_left          float64
# sight_right         float64
# hear_left           float64
# hear_right          float64
# SBP                 float64
# DBP                 float64
# BLDS                float64
# tot_chole           float64
# HDL_chole           float64
# LDL_chole           float64
# triglyceride        float64
# hemoglobin          float64
# urine_protein       float64
# serum_creatinine    float64
# SGOT_AST            float64
# SGOT_ALT            float64
# gamma_GTP           float64
# SMK_stat_type_cd    float64
# DRK_YN               object
# dtype: object

# %% [markdown]
# DELETING THE COLUMS THAT I THINK ARE IRREVELANT TO DECTECT DRINKERS OR SMOKERS OR ARE CHANGED ONLY AS A RESULT OF MUCH PROLONGED SMOKING AND DRINKING

# %%
df=df.drop(['waistline','sight_left','sight_right','hear_left','hear_right','hemoglobin','serum_creatinine'], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-61-48cf314e9aef> in <cell line: 1>()
# ----> 1 df=df.drop(['waistline','sight_left','sight_right','hear_left','hear_right','hemoglobin','serum_creatinine'], axis=1)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5397                 weight  1.0     0.8
#    5398         """
# -> 5399         return super().drop(
#    5400             labels=labels,
#    5401             axis=axis,
#
# ...

# %%
df.drop(['sex' ,'age' ] , axis=1)
# Out:
#           SBP    DBP   BLDS  tot_chole  HDL_chole  LDL_chole  triglyceride  \
# 0       120.0   80.0   99.0      193.0       48.0      126.0          92.0
# 1       130.0   82.0  106.0      228.0       55.0      148.0         121.0
# 2       120.0   70.0   98.0      136.0       41.0       74.0         104.0
# 3       145.0   87.0   95.0      201.0       76.0      104.0         106.0
# 4       138.0   82.0  101.0      199.0       61.0      117.0         104.0
# ...       ...    ...    ...        ...        ...        ...           ...
# 210984  117.0   78.0  114.0      236.0       56.0      158.0         111.0
# 210985  140.0  100.0  114.0      170.0       61.0       93.0          79.0
# 210986  124.0   84.0  231.0      200.0       28.0       94.0         527.0
# 210987  125.0   78.0   89.0      239.0       58.0      149.0         155.0
# 210988  115.0   74.0  109.0      195.0       61.0      117.0          85.0
#
# ...

# %%
df.head(5)
# Out:
#     sex  age    SBP   DBP   BLDS  tot_chole  HDL_chole  LDL_chole  \
# 0  Male   35  120.0  80.0   99.0      193.0       48.0      126.0
# 1  Male   30  130.0  82.0  106.0      228.0       55.0      148.0
# 2  Male   40  120.0  70.0   98.0      136.0       41.0       74.0
# 3  Male   50  145.0  87.0   95.0      201.0       76.0      104.0
# 4  Male   50  138.0  82.0  101.0      199.0       61.0      117.0
#
#    triglyceride  urine_protein  SGOT_AST  SGOT_ALT  gamma_GTP  \
# 0          92.0            1.0      21.0      35.0       40.0
# 1         121.0            1.0      20.0      36.0       27.0
# 2         104.0            1.0      47.0      32.0       68.0
# 3         106.0            1.0      29.0      34.0       18.0
# 4         104.0            1.0      19.0      12.0       25.0
#
#    SMK_stat_type_cd DRK_YN        BMI
# 0               1.0      Y  25.951557
# 1               3.0      N  24.691358
# 2               1.0      N  27.548209
# ...

# %%
df=df.drop_duplicates()

# %% [markdown]
# DROPPING DUPLICATE VALUES

# %% [markdown]
# DROPPING NULL VALUES

# %%
print(df.isnull().sum())
# Out:
# sex                 0
# age                 0
# SBP                 0
# DBP                 0
# BLDS                0
# tot_chole           0
# HDL_chole           0
# LDL_chole           0
# triglyceride        0
# urine_protein       0
# SGOT_AST            0
# SGOT_ALT            0
# gamma_GTP           0
# SMK_stat_type_cd    0
# DRK_YN              0
# BMI                 0
# dtype: int64

# %%
df=df.dropna()

# %%
df.isnull()
# Out:
#           sex    age    SBP    DBP   BLDS  tot_chole  HDL_chole  LDL_chole  \
# 0       False  False  False  False  False      False      False      False
# 1       False  False  False  False  False      False      False      False
# 2       False  False  False  False  False      False      False      False
# 3       False  False  False  False  False      False      False      False
# 4       False  False  False  False  False      False      False      False
# ...       ...    ...    ...    ...    ...        ...        ...        ...
# 210984  False  False  False  False  False      False      False      False
# 210985  False  False  False  False  False      False      False      False
# 210986  False  False  False  False  False      False      False      False
# 210987  False  False  False  False  False      False      False      False
# 210988  False  False  False  False  False      False      False      False
#
# ...

# %% [markdown]
# RECONFIRMING WE DO NOT HAVE ANY NULL VALUES

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <Axes: >

# %% [markdown]
# NO MARKINGS MEANS NO ERROR

# %%
print(df.isnull().sum())
# Out:
# sex                 0
# age                 0
# SBP                 0
# DBP                 0
# BLDS                0
# tot_chole           0
# HDL_chole           0
# LDL_chole           0
# triglyceride        0
# urine_protein       0
# SGOT_AST            0
# SGOT_ALT            0
# gamma_GTP           0
# SMK_stat_type_cd    0
# DRK_YN              0
# BMI                 0
# dtype: int64

# %% [markdown]
# ADDING A NEW COLUMN OF BMI TO ELIMINATE OUTLINER BODY SIGNALS

# %%
df['BMI']=df['weight']*10000/(df['height']**2)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'weight'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df.head(5)
# Out:
#     sex  age  height  weight    SBP   DBP   BLDS  tot_chole  HDL_chole  \
# 0  Male   35   170.0    75.0  120.0  80.0   99.0      193.0       48.0
# 1  Male   30   180.0    80.0  130.0  82.0  106.0      228.0       55.0
# 2  Male   40   165.0    75.0  120.0  70.0   98.0      136.0       41.0
# 3  Male   50   175.0    80.0  145.0  87.0   95.0      201.0       76.0
# 4  Male   50   165.0    60.0  138.0  82.0  101.0      199.0       61.0
#
#    LDL_chole  triglyceride  urine_protein  SGOT_AST  SGOT_ALT  gamma_GTP  \
# 0      126.0          92.0            1.0      21.0      35.0       40.0
# 1      148.0         121.0            1.0      20.0      36.0       27.0
# 2       74.0         104.0            1.0      47.0      32.0       68.0
# 3      104.0         106.0            1.0      29.0      34.0       18.0
# 4      117.0         104.0            1.0      19.0      12.0       25.0
#
#    SMK_stat_type_cd DRK_YN        BMI
# 0               1.0      Y  25.951557
# ...

# %%
df=df.drop(['height' , 'weight'],axis=1)

# %% [markdown]
# OUTLINERS:VERY HIGH OR VERY LOW

# %%
Q1=df.quantile(0.25)
Q3=df.quantile(0.75)
IQR= Q3-Q1
print(IQR)
# Out:
# age                 25.000000
# SBP                 19.000000
# DBP                 12.000000
# BLDS                17.000000
# tot_chole           50.000000
# HDL_chole           20.000000
# LDL_chole           46.000000
# triglyceride        86.000000
# urine_protein        0.000000
# SGOT_AST             9.000000
# SGOT_ALT            15.000000
# gamma_GTP           24.000000
# SMK_stat_type_cd     1.000000
# BMI                  4.467182
# dtype: float64
# <ipython-input-48-977baf1b0057>:1: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Q1=df.quantile(0.25)
# ...

# %%
sns.boxplot(df['tot_chole'])
# Out:
# <Axes: >

# %% [markdown]
# NO OUTLINERS AFTER IQR

# %%
sns.boxplot(df['BMI'])
# Out:
# <Axes: >

# %%
sns.boxplot(df['gamma_GTP'])
# Out:
# <Axes: >

# %%
sns.boxplot(df['urine_protein'])
# Out:
# <Axes: >

# %%
sns.boxplot(df['SGOT_ALT'])
# Out:
# <Axes: >

# %%
df.describe()
# Out:
#                  age         height         weight            SBP  \
# count  210988.000000  210987.000000  210987.000000  210987.000000
# mean       47.623585     162.274785      63.324257     122.424699
# std        14.167843       9.280266      12.542313      14.512893
# min         5.000000     130.000000      25.000000      72.000000
# 25%        35.000000     155.000000      55.000000     112.000000
# 50%        45.000000     160.000000      60.000000     120.000000
# 75%        60.000000     170.000000      70.000000     131.000000
# max        85.000000     190.000000     140.000000     241.000000
#
#                  DBP           BLDS      tot_chole      HDL_chole  \
# count  210987.000000  210987.000000  210987.000000  210987.000000
# mean       76.065487     100.485831     195.631096      56.988412
# std         9.893418      24.214551      38.427611      23.173595
# min        36.000000      38.000000      54.000000       2.000000
# ...

# %%
sns.countplot(x='gamma_GTP', data=df)
# Out:
# <Axes: xlabel='gamma_GTP', ylabel='count'>

# %%
sns.boxplot(x='urine_protein' , y='DRK_YN',data=df)
# Out:
# <Axes: xlabel='urine_protein', ylabel='DRK_YN'>

# %%
sns.boxplot(x='tot_chole' , y='DRK_YN', data=df)
# Out:
# <Axes: xlabel='tot_chole', ylabel='DRK_YN'>

# %%
sns.boxplot(x='gamma_GTP' , y='DRK_YN' , data=df)
# Out:
# <Axes: xlabel='gamma_GTP', ylabel='DRK_YN'>

# %% [markdown]
# as visible from graphs there are alot of ouliners which needs to be eliminated for ml model to work efficinetly

# %%
sns.histplot(data=df)
plt.title('histogram of data')
plt.show()

# %%
variables_to_filter=['tot_chole','SGOT_AST','SGOT_ALT','gamma_GTP','HDL_chole','triglyceride','urine_protein','BMI','LDL_chole']
filtered_data=pd.DataFrame()
for variable in variables_to_filter:
  Q1=df[variable].quantile(0.25)
  Q3=df[variable].quantile(0.75)
  IQR=Q3-Q1
  lower_bound=Q1-1.5*IQR
  upper_bound=Q3+1.5*IQR
  filtered_variable_data=df[(df[variable] >=lower_bound) & (df[variable]<=upper_bound)]
  filtered_data[variable]=filtered_variable_data[variable]
  filtered_data.to_csv('filtered_dataset.csv', index=False)

# %%
filtered_data=pd.read_csv('/content/filtered_dataset.csv')

# %%
filtered_data.dtypes
# Out:
# tot_chole        float64
# SGOT_AST         float64
# SGOT_ALT         float64
# gamma_GTP        float64
# HDL_chole        float64
# triglyceride     float64
# urine_protein    float64
# BMI              float64
# LDL_chole        float64
# dtype: object

# %%
filtered_data.isnull()
# Out:
#         tot_chole  SGOT_AST  SGOT_ALT  gamma_GTP  HDL_chole  triglyceride  \
# 0           False     False     False      False      False         False
# 1           False     False     False      False      False         False
# 2           False      True     False      False      False         False
# 3           False     False     False      False      False         False
# 4           False     False     False      False      False         False
# ...           ...       ...       ...        ...        ...           ...
# 208568      False     False     False      False      False         False
# 208569      False     False     False      False      False         False
# 208570      False     False      True      False      False          True
# 208571      False     False     False      False      False         False
# 208572      False     False     False      False      False         False
#
#         urine_protein    BMI  LDL_chole    age  DRK_YN
# ...

# %%
columns_to_add=['age','DRK_YN']
filtered_data=pd.merge(filtered_data,df[columns_to_add], left_index= True, right_index=True,how='left')

# %%
sns.boxplot(x='tot_chole' , data=filtered_data)
# Out:
# <Axes: xlabel='tot_chole'>

# %% [markdown]
# LESS OUTLIERS ALL CANNOT BE ELIMINATED

# %%
filtered_data.isnull().sum()
# Out:
# tot_chole            0
# SGOT_AST         14002
# SGOT_ALT         13717
# gamma_GTP        18279
# HDL_chole         2861
# triglyceride     11179
# urine_protein    11864
# BMI               4013
# LDL_chole          776
# age                  2
# DRK_YN               2
# dtype: int64

# %%
filtered_data=filtered_data.dropna()

# %%
# @title
filtered_data.isnull().sum()
# Out:
# tot_chole        0
# SGOT_AST         0
# SGOT_ALT         0
# gamma_GTP        0
# HDL_chole        0
# triglyceride     0
# urine_protein    0
# BMI              0
# LDL_chole        0
# age              0
# DRK_YN           0
# dtype: int64

# %%
from sklearn.model_selection import  train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score,confusion_matrix, classification_report
from sklearn.ensemble import HistGradientBoostingClassifier
from sklearn.ensemble import HistGradientBoostingRegressor
import time
get_ipython.system_pip_install_memory_profiler
from memory_profiler import memeory_usage
def mem_usage():
    mem = memeory_usage(-1, interval=1, timeout=None)
    return max(mem)
target_variable='DRK_YN'
X=filtered_data.drop(columns=['DRK_YN'])
Y=filtered_data['DRK_YN']
X_train , X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.2,random_state=42)
scaler=StandardScaler()
mem_usage_before=mem_usage()
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)
model=LogisticRegression(random_state=42)
start_time=time.process_time()
model.fit(X_train,Y_train)
end_time=time.process_time()
mem_usage_after=mem_usage()
Y_pred = model.predict(X_test)
accuracy=accuracy_score(Y_test,Y_pred)
classification_report_str=classification_report(Y_test, Y_pred)
execution_time=end_time-start_time
print(f'Accuracy:{accuracy:.2f}')
print('Classification Report:')
print(classification_report_str)
print(f"Execution Time (seconds): {execution_time}")
print(f"Peak Memory Usage (MiB):{mem_usage_after-mem_usage_before:.2f}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-149-4fee2fd59c5c> in <cell line: 8>()
#       6 from sklearn.ensemble import HistGradientBoostingRegressor
#       7 import time
# ----> 8 get_ipython.system_pip_install_memory_profiler
#       9 from memory_profiler import memeory_usage
#      10 def mem_usage():
#
# AttributeError: 'function' object has no attribute 'system_pip_install_memory_profiler'

# %%
from sklearn.tree import DecisionTreeClassifier
X=np.random.rand(208573,10)
Y=np.random.randint(2, size=208573)
model=DecisionTreeClassifier(random_state=42)
model.fit(X_train, Y_train)
Y_pred=model.predict(X_test)
accuracy=accuracy_score(Y_test, Y_pred)
confusion=confusion_matrix(Y_test, Y_pred)
report=classification_report(Y_test,Y_pred)
print(f"Accuracy:{accuracy}")
print(f"Confusion Matrix:\n{confusion}")
print(f"Classification Report:\n{report}")
# Out:
# Accuracy:0.5433867957356616
# Confusion Matrix:
# [[8657 7168]
#  [7266 8520]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            N       0.54      0.55      0.55     15825
#            Y       0.54      0.54      0.54     15786
#
#     accuracy                           0.54     31611
#    macro avg       0.54      0.54      0.54     31611
# weighted avg       0.54      0.54      0.54     31611

# %%
from sklearn.naive_bayes import GaussianNB
X=np.random.rand(208573,10)
Y=np.random.randint(2,size=208573)
model=GaussianNB()
model.fit(X_train, Y_train)
Y_pred=model.predict(X_test)
accuracy=accuracy_score(Y_test, Y_pred)
confusion=confusion_matrix(Y_test,Y_pred)
report=classification_report(Y_test, Y_pred)
print(f"Accuracy:{accuracy}")
print(f"Classification Report:\n{report}")
# Out:
# Accuracy:0.6192148302805985
# Classification Report:
#               precision    recall  f1-score   support
#
#            N       0.63      0.57      0.60     15825
#            Y       0.61      0.67      0.64     15786
#
#     accuracy                           0.62     31611
#    macro avg       0.62      0.62      0.62     31611
# weighted avg       0.62      0.62      0.62     31611

# %%
from sklearn.neighbours import KNeighborsClassifier
import time
# !pip install sklearn.neighbours
from memory_profiler import memory_usage
def mem_usage():
    mem=memory_usage(-1, interval=1, timeout=None)
    return max(mem)
X=np.random.rand(208573,10)
Y=np.random.randint(2,size=208573)
model = KNeighboursClassifier(n_neighbours=10)
start_time=time.process_time()
model.fit(X_train, Y_train)
end_time= time.process_time()
mem_usage_after=mem_usage()
Y_pred=model.predict(X_test)
accuracy=accuracy_score(Y_test, Y_pred)
confusion=confusion_matrix(Y_test, Y_pred)
report=classification_report(Y_test,Y_pred)
execution_time=end_time-start_time
print(f"Accuracy: {accuracy}")
print(f"Confusion Matrix: \n{confusion}")
print(f"Classification Report :\n{report}")
print(f"Execution Time (seconds): {execution_time}")
print(f"Peak Memory Usage (MiB): {mem_usage_after - mem_usage_before: .2f}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-143-92cae514ec93> in <cell line: 1>()
# ----> 1 from sklearn.neighbours import KNeighborsClassifier
#       2 import time
#       3 get_ipython().system('pip install sklearn.neighbours')
#       4 from memory_profiler import memory_usage
#       5 def mem_usage():
#
# ModuleNotFoundError: No module named 'sklearn.neighbours'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# naive bayes is better than decision tree in perecision
